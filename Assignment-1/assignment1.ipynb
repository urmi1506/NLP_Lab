# %%
# %pip install nltk textblob
# Out:
# Collecting nltk
#   Using cached nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting textblob
#   Downloading textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting click (from nltk)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting joblib (from nltk)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Using cached regex-2025.11.3-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\nlp_lab\.venv\lib\site-packages (from click->nltk) (0.4.6)
# Using cached nltk-3.9.2-py3-none-any.whl (1.5 MB)
# Downloading textblob-0.19.0-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------------------------------- 624.3/624.3 kB 11.3 MB/s  0:00:00
# Using cached regex-2025.11.3-cp312-cp312-win_amd64.whl (277 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, joblib, click, nltk, textblob
#
#    ---------------------------------------- 0/6 [tqdm]
#    ---------------------------------------- 0/6 [tqdm]
#    ---------------------------------------- 0/6 [tqdm]
#    ---------------------------------------- 0/6 [tqdm]
#    ---------------------------------------- 0/6 [tqdm]
#    ---------------------------------------- 0/6 [tqdm]
#    ---------------------------------------- 0/6 [tqdm]
#    ------ --------------------------------- 1/6 [regex]
#    ------ --------------------------------- 1/6 [regex]
#    ------ --------------------------------- 1/6 [regex]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    -------------------- ------------------- 3/6 [click]
#    -------------------- ------------------- 3/6 [click]
#    -------------------- ------------------- 3/6 [click]
#    -------------------- ------------------- 3/6 [click]
#    -------------------- ------------------- 3/6 [click]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    --------------------------------- ------ 5/6 [textblob]
#    --------------------------------- ------ 5/6 [textblob]
#    --------------------------------- ------ 5/6 [textblob]
#    --------------------------------- ------ 5/6 [textblob]
#    --------------------------------- ------ 5/6 [textblob]
#    ---------------------------------------- 6/6 [textblob]
#
# Successfully installed click-8.3.1 joblib-1.5.3 nltk-3.9.2 regex-2025.11.3 textblob-0.19.0 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_percepton_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\urmi1506\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\urmi1506\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\urmi1506\AppData\Roaming\nltk_data...
# [nltk_data] Error loading averaged_percepton_tagger: Package
# [nltk_data]     'averaged_percepton_tagger' not found in index
# False

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer,WordNetLemmatizer
from textblob import TextBlob

# %%
text = "I went on a vacation to the mountains with my family. The weather was pleasant and the scenery was beautiful. We enjoyed trekking, local food, and peaceful evenings near the river. The trip made me feel relaxed, happy, and refreshed."

# %%
token = word_tokenize(text)
print("Tokens")
print(token)
# Out:
# Tokens
# ['I', 'went', 'on', 'a', 'vacation', 'to', 'the', 'mountains', 'with', 'my', 'family', '.', 'The', 'weather', 'was', 'pleasant', 'and', 'the', 'scenery', 'was', 'beautiful', '.', 'We', 'enjoyed', 'trekking', ',', 'local', 'food', ',', 'and', 'peaceful', 'evenings', 'near', 'the', 'river', '.', 'The', 'trip', 'made', 'me', 'feel', 'relaxed', ',', 'happy', ',', 'and', 'refreshed', '.']

# %%
stemmer =PorterStemmer()
stem = [stemmer.stem(word) for word in token]
print("Stemming")
print(stem)
# Out:
# Stemming
# ['i', 'went', 'on', 'a', 'vacat', 'to', 'the', 'mountain', 'with', 'my', 'famili', '.', 'the', 'weather', 'wa', 'pleasant', 'and', 'the', 'sceneri', 'wa', 'beauti', '.', 'we', 'enjoy', 'trek', ',', 'local', 'food', ',', 'and', 'peac', 'even', 'near', 'the', 'river', '.', 'the', 'trip', 'made', 'me', 'feel', 'relax', ',', 'happi', ',', 'and', 'refresh', '.']

# %%
lemmatizer= WordNetLemmatizer()
lemmas =[lemmatizer.lemmatize(word) for word in token]
print("Lemmatizer")
print(lemmas)
# Out:
# Lemmatizer
# ['I', 'went', 'on', 'a', 'vacation', 'to', 'the', 'mountain', 'with', 'my', 'family', '.', 'The', 'weather', 'wa', 'pleasant', 'and', 'the', 'scenery', 'wa', 'beautiful', '.', 'We', 'enjoyed', 'trekking', ',', 'local', 'food', ',', 'and', 'peaceful', 'evening', 'near', 'the', 'river', '.', 'The', 'trip', 'made', 'me', 'feel', 'relaxed', ',', 'happy', ',', 'and', 'refreshed', '.']

# %%
pos_tags = nltk.pos_tag(token)
print("POS Tagging")
print(pos_tags)
# Out:
# POS Tagging
# [('I', 'PRP'), ('went', 'VBD'), ('on', 'IN'), ('a', 'DT'), ('vacation', 'NN'), ('to', 'TO'), ('the', 'DT'), ('mountains', 'NNS'), ('with', 'IN'), ('my', 'PRP$'), ('family', 'NN'), ('.', '.'), ('The', 'DT'), ('weather', 'NN'), ('was', 'VBD'), ('pleasant', 'JJ'), ('and', 'CC'), ('the', 'DT'), ('scenery', 'NN'), ('was', 'VBD'), ('beautiful', 'JJ'), ('.', '.'), ('We', 'PRP'), ('enjoyed', 'VBD'), ('trekking', 'VBG'), (',', ','), ('local', 'JJ'), ('food', 'NN'), (',', ','), ('and', 'CC'), ('peaceful', 'JJ'), ('evenings', 'NNS'), ('near', 'IN'), ('the', 'DT'), ('river', 'NN'), ('.', '.'), ('The', 'DT'), ('trip', 'NN'), ('made', 'VBD'), ('me', 'PRP'), ('feel', 'VB'), ('relaxed', 'JJ'), (',', ','), ('happy', 'JJ'), (',', ','), ('and', 'CC'), ('refreshed', 'VBD'), ('.', '.')]

# %%
blob = TextBlob(text)
sentiment = blob.sentiment

print("Sentiment Analysis")
print("Polarity",sentiment.polarity)
print("Subjectivity",sentiment.subjectivity)

if sentiment.polarity > 0:
    print("Overall Positive Sentiment")

elif sentiment.polarity < 0:
    print("Overall Negative Sentiment")

else:
    print("Neutral Sentiment")
# Out:
# Sentiment Analysis
# Polarity 0.46190476190476193
# Subjectivity 0.6523809523809524
# Overall Positive Sentiment
